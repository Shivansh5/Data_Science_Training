# %% [markdown]
# # Notes:
# # First we do univarient analysis.
# ###	For categorical variable we use.
# 		countplot(sns.countplot) BarGraph
# 		piechart(.plot(kind="pie"))
# ###	For Numerical variable we use.
# 		histogram(sns.histplot(df["Age"]))
# 		distplot(sns.distplot())
# 		boxplot(sns.boxplot())
# # Second we do bivarient or Multivarient analysis.
# ###	Numerical - Numerical
# 		Scatterplot(sns.scatterplot)
# ###	Categorical-Categorical
# 		Heatmap(sns.heatmap)
# ###	Numerical - Categorical
# 		Barplot(sns.barplot)-(# First we write categorical(Pcalss)and then we write Numerical(Age))
# ###	Numerical - Categorical
# 		Boxplot(sns.boxplot)
# ###	Numerical - Categorical
# 		Distplot(sns.distplot)-
# 		(sns.distplot(ti[ti["Survived"]==0]
# 		["Age"],hist=False,label="Not Sur")
# 		sns.distplot(ti[ti["Survived"]==1]
# 		["Age"],hist=False,label="Sur")
# 		plt.legend() )

# %%
pd.crosstab(ti["Pclass"],ti["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = sns.load_dataset("tips")

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 144       16.43  2.30  Female     No  Thur   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 157       25.00  3.75  Female     No   Sun  Dinner     4
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2

# %%
ti = pd.read_csv("train.csv")

# %%
ti.sample()
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 127          128         1       3  Madsen, Mr. Fridtjof Arne  male  24.0
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 127      0      0  C 17369  7.1417   NaN        S

# %%
flight = sns.load_dataset("flights")

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris= sns.load_dataset("iris")

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 25            5.0          3.0           1.6          0.2      setosa
# 73            6.1          2.8           4.7          1.2  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 124           6.7          3.3           5.7          2.1   virginica

# %% [markdown]
# # 1.Scatterplot
# # Numerical - Numerical

# %% [markdown]
# # Bivarient

# %%
df.sample()
# Out:
#     total_bill  tip   sex smoker  day    time  size
# 98       21.01  3.0  Male    Yes  Fri  Dinner     2

# %% [markdown]
# ## we use sns.scatterplot not plt.scatter because sns.scatterplot has hue parameter

# %%
# Relation between total_bill and tip
plt.style.use("fivethirtyeight")
sns.scatterplot(df["total_bill"],df["tip"],color="pink")
#plt.xlabel("Total_Bill")
#plt.ylabel("Tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
t5 = df["total_bill"].astype('int64')
t6 = df["tip"].astype('int64')

# %% [markdown]
# # Multivarient

# %%
df.sample()
# Out:
#     total_bill  tip   sex smoker   day   time  size
# 80       19.44  3.0  Male    Yes  Thur  Lunch     2

# %% [markdown]
# #### Set graph size

# %%
sns.set(rc={'figure.figsize':(9.7,5.27)})

# %%
sns.scatterplot(df["total_bill"],df["tip"],hue=df["sex"],style=df["smoker"],size=df["size"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Barplot
# # Numerical - Categorical

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# First we write categorical(Pcalss) and then we write  Numerical(Age)
sns.barplot(ti["Pclass"],ti["Age"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(ti["Pclass"],ti["Fare"],hue=ti["Sex"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(ti["Pclass"],ti["Age"],hue=ti["Sex"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 3. Boxplot
# # Numerical - Categorical

# %%
ti.sample()
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 456          457         0       1  Millet, Mr. Francis Davis  male  65.0
#
#      SibSp  Parch Ticket   Fare Cabin Embarked
# 456      0      0  13509  26.55   E38        S

# %%
sns.boxplot(ti["Pclass"],ti["Age"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(ti["Sex"],ti["Age"],hue=ti["Survived"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4.Distplot
# # Numerical - Categorical

# %%
sns.distplot(ti[ti["Survived"]==0]["Age"],hist=False,label="Not Sur")
sns.distplot(ti[ti["Survived"]==1]["Age"],hist=False,label="Sur")
plt.legend()

# %% [markdown]
# # 5.Heatmap
# # Categorical-Categorical

# %%
ti.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
pd.crosstab(ti["Pclass"],ti["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
pd.crosstab(ti["Pclass"],ti["Sex"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
sns.heatmap(pd.crosstab(ti["Pclass"],ti["Sex"]))
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Pclass'>

# %%
ti.groupby("Embarked").mean()["Survived"]
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
# ti["Embarked"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_187358/179533829.py in <module>
# ----> 1 ti["Embarked"].mean()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
# ...

# %% [markdown]
# # 6.Pairplot
# # It plot scatterplot for every cloumn to every column

# %%
sns.pairplot(ti)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(df)

# %% [markdown]
# # 7.Lineplot
# # Numerical - Numerical
# # Used to time or year based numbers

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df2 = flight.groupby("year")

# %%
df2.sum()["passengers"].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
new  = df2.sum().reset_index()

# %%
sns.lineplot(new["year"],new["passengers"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

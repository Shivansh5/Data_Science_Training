# %% [markdown]
# # Part-1

# %%
import pandas as pd

# %%
# !ls
# Out:
# __MACOSX	 so_survey_2019.pdf	    survey_results_schema.csv
# README_2019.txt  survey_results_public.csv  Untitled.ipynb

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school            NaN
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
# Shape is an attribute not method
df.shape
# Out:
# (88883, 85)

# %%
# object means string
#df.info()

# %%
pd.set_option("display.max_columns",85)

# %%
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
pd.set_option("display.max_rows",85)

# %% [markdown]
# # Part-2

# %% [markdown]
# # A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.

# %%
people={
    "first":["shivansh","shivam","golu"],
    "last" :["kumar","dey","dey"],
    "email":["shivansh@gmail.com","shivam@gmail.com","golu@gmail.com"]
}
#json format

# %%
type(people)
# Out:
# dict

# %%
people["email"]
# Out:
# ['shivansh@gmail.com', 'shivam@gmail.com', 'golu@gmail.com']

# %%
df1=pd.DataFrame(people)

# %%
df1
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %%
df1["email"]
# Out:
# 0    shivansh@gmail.com
# 1      shivam@gmail.com
# 2        golu@gmail.com
# Name: email, dtype: object

# %%
type(df1["email"])
# Out:
# pandas.core.series.Series

# %%
# df1["email"]
df1.email
# Out:
# 0    shivansh@gmail.com
# 1      shivam@gmail.com
# 2        golu@gmail.com
# Name: email, dtype: object

# %%
df1[["first","email"]]
# Out:
#       first               email
# 0  shivansh  shivansh@gmail.com
# 1    shivam    shivam@gmail.com
# 2      golu      golu@gmail.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %% [markdown]
# # loc :- Label wise
# # iloc :- Index wise

# %%
df1.loc[0:2]
# Out:
#     first   last             email
# 0    Raju  Kumar    Raju@gmail.com
# 1  shivam    dey  shivam@gmail.com
# 2    golu    dey    golu@gmail.com

# %%
df1.loc[0:2,["first"]] # Label wise
# Out:
#       first
# 0  shivansh
# 1    shivam
# 2      golu

# %%
df1.loc[0:2,["first","last"]]
# Out:
#       first   last
# 0  shivansh  kumar
# 1    shivam    dey
# 2      golu    dey

# %%
df1.loc[:,"first":"email"]
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %% [markdown]
# # iloc

# %%
# In iloc last index excluded 
df1.iloc[0:2]
# Out:
#     first   last             email
# 0    Raju  Kumar    Raju@gmail.com
# 1  shivam    dey  shivam@gmail.com

# %%
df1.iloc[0:2,2] # Index wise
# Out:
# 0    shivansh@gmail.com
# 1      shivam@gmail.com
# Name: email, dtype: object

# %%
df1.iloc[:,[-1]]
# Out:
#                 email
# 0  shivansh@gmail.com
# 1    shivam@gmail.com
# 2      golu@gmail.com

# %%
df1.iloc[:,0:-1]
# Out:
#       first   last
# 0  shivansh  kumar
# 1    shivam    dey
# 2      golu    dey

# %%
#x=df1.iloc[:,0:-1]
#y=df1.iloc[:,[-1]]

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school            NaN
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %% [markdown]
# # Part-3
# # Make index to Respomdent

# %%
df5=pd.read_csv("survey_results_public.csv",index_col="Respondent")

# %%
df5.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther OrgSize DevType  \
# Respondent
# 1           Taught yourself a new language, framework, or ...     NaN     NaN
#
#            YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot  \
# Respondent
# 1                  4         10          NaN       NaN    NaN      NaN
#
# ...

# %% [markdown]
# # Part-4
# # FILTERING

# %%
df1
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %%
df1["last"] == "dey"
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df1[df1["last"]=="dey"]
# Out:
#     first last             email
# 1  shivam  dey  shivam@gmail.com
# 2    golu  dey    golu@gmail.com

# %%
filt = (df1["last"]=="dey")

# %%
df1.loc[filt]
# Out:
#     first last             email
# 1  shivam  dey  shivam@gmail.com
# 2    golu  dey    golu@gmail.com

# %%
filt1 = (df1["last"]=="dey") | (df1["first"]=="shivansh")

# %%
df1[filt1]
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %%
df1.loc[filt1,"email"]
# Out:
# 0    shivansh@gmail.com
# 1      shivam@gmail.com
# 2        golu@gmail.com
# Name: email, dtype: object

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school            NaN
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
high_sal = df["ConvertedComp"]>80000

# %%
df.loc[high_sal,["ConvertedComp","Country","LanguageWorkedWith"]]
# Out:
#        ConvertedComp         Country  \
# 5           366420.0          Canada
# 8            95179.0     New Zealand
# 12           90000.0   United States
# 15          455352.0  United Kingdom
# 21          103000.0   United States
# ...              ...             ...
# 88323       180000.0   United States
# 88324      2000000.0   United States
# 88325       130000.0   United States
# 88326        82488.0         Finland
# 88329       588012.0     Netherlands
#
#                                       LanguageWorkedWith
# 5                                             Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# ...

# %%
countries = ["United States","India","United Kingdom","Germeny","Canada"]

# %%
# Bool Values
filt = df["Country"].isin(countries)

# %%
df.loc[filt,["Country","ConvertedComp","LanguageWorkedWith",]]
# Out:
#               Country  ConvertedComp  \
# 0      United Kingdom            NaN
# 3       United States        61000.0
# 5              Canada       366420.0
# 7               India            NaN
# 9               India        13293.0
# ...               ...            ...
# 88859   United States            NaN
# 88863  United Kingdom            NaN
# 88864           India            NaN
# 88877   United States            NaN
# 88878          Canada            NaN
#
#                                       LanguageWorkedWith
# 0                        HTML/CSS;Java;JavaScript;Python
# 3                                    C;C++;C#;Python;SQL
# 5                                             Java;R;SQL
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9                          C#;Go;JavaScript;Python;R;SQL
# ...                                                  ...
# 88859                                        Go;HTML/CSS
# ...

# %%
filte = df["LanguageWorkedWith"].str.contains("Python",na=False)

# %%
df.loc[filte,["LanguageWorkedWith","ConvertedComp"]]
# Out:
#                                       LanguageWorkedWith  ConvertedComp
# 0                        HTML/CSS;Java;JavaScript;Python            NaN
# 1                                    C++;HTML/CSS;Python            NaN
# 3                                    C;C++;C#;Python;SQL        61000.0
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA            NaN
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...                                                  ...            ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# 88860    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):            NaN
# 88865    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):            NaN
# 88872           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL            NaN
# 88876                         HTML/CSS;JavaScript;Python            NaN
#
# [36443 rows x 2 columns]

# %% [markdown]
# # Part-5
# # Modifying

# %%
df1
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.columns = ["first_name","last_name","email_id"]

# %%
df1
# Out:
#   first_name last_name            email_id
# 0   shivansh     kumar  shivansh@gmail.com
# 1     shivam       dey    shivam@gmail.com
# 2       golu       dey      golu@gmail.com

# %%
# Column name convert into UpperCase

# %%
df1.columns = [x.upper() for x in df1.columns]

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME            EMAIL_ID
# 0   shivansh     kumar  shivansh@gmail.com
# 1     shivam       dey    shivam@gmail.com
# 2       golu       dey      golu@gmail.com

# %%
# Rename Columns

# %%
df1.rename(columns={"FIRST_NAME":"first","LAST_NAME":"last","EMAIL_ID":"email"},inplace=True)

# %%
df1
# Out:
#       first   last               email
# 0  shivansh  kumar  shivansh@gmail.com
# 1    shivam    dey    shivam@gmail.com
# 2      golu    dey      golu@gmail.com

# %%
# Replace Column

# %%
df1.loc[0]=["Raju","Kumar","Raju@gmail.com"]

# %%
df1
# Out:
#     first   last             email
# 0    Raju  Kumar    Raju@gmail.com
# 1  shivam    dey  shivam@gmail.com
# 2    golu    dey    golu@gmail.com

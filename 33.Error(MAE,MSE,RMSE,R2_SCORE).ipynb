# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('placement02.csv')

# %%
df.head()
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_test,lr.predict(X_test),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
type(y_test)  , type(y_test.values)
# Out:
# (pandas.core.series.Series, numpy.ndarray)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %% [markdown]
# #### The Mean absolute error represents the average of the absolute difference between the actual and predicted values in the dataset. It measures the average of the residuals in the dataset.
# <img src="https://miro.medium.com/max/318/1*_mx6zD6Qw_1sYEvWszK5Nw.png" />
#
# <img src="https://miro.medium.com/max/411/1*3DI_3QdQgyBWixpRxTgCHQ.png" />

# %%
print("MAE : ",mean_absolute_error(y_test,y_pred))
# Out:
# MAE :  0.2884710931878175

# %% [markdown]
# ##### Mean Squared Error represents the average of the squared difference between the original and predicted values in the data set. It measures the variance of the residuals.
# <img src="https://miro.medium.com/max/293/1*1TV6T6hNP-iwJrtvfsvCRQ.png" />
#
# #### Residual is the difference between the observed value and the mean value that the model predicts for that observation.

# %%
print("MSE : ",mean_squared_error(y_test,y_pred))
# Out:
# MSE :  0.12129235313495527

# %% [markdown]
# ##### Root Mean Squared Error is the square root of Mean Squared error. It measures the standard deviation of residuals.
# <img src ="https://miro.medium.com/max/468/1*usaMSyi6jUT3f2bOMyiYdA.png" />

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# <img src="https://miro.medium.com/max/288/1*bBrMI54b85FGilV_ciAL-Q.png" />
#
# #### Adjusted R squared is a modified version of R square, and it is adjusted for the number of independent variables in the model, and it will always be less than or equal to R².In the formula below n is the number of observations in the data and k is the number of the independent variables in the data.

# %%
print("MSE",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# MSE 0.780730147510384

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %% [markdown]
# # Conclusion

# %% [markdown]
# # For comparing the accuracy among different linear regression models, RMSE is a better choice than R Squared.

# %% [markdown]
# # Therefore, if comparing the prediction accuracy among different linear regression (LR)models then RMSE is a better option as it is simple to calculate and differentiable. However, if your dataset has outliers then choose MAE over RMSE.

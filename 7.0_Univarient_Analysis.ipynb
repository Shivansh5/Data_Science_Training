# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 800          801         0       2
# 680          681         0       3
# 599          600         1       1
# 877          878         0       3
# 145          146         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 800                          Ponesell, Mr. Martin    male  34.0      0      0
# 680                           Peters, Miss. Katie  female   NaN      0      0
# 599  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1      0
# 877                          Petroff, Mr. Nedelio    male  19.0      0      0
# 145                  Nicholls, Mr. Joseph Charles    male  19.0      1      1
#
#          Ticket     Fare Cabin Embarked
# 800      250647  13.0000   NaN        S
# 680      330935   8.1375   NaN        Q
# 599    PC 17485  56.9292   A20        C
# 877      349212   7.8958   NaN        S
# 145  C.A. 33112  36.7500   NaN        S

# %% [markdown]
# # 1. Categorical Data
# ## a. countplot
# ## b. piechart
# # If you are doing univariant analysis for categorical data so you go with Countplot and piechart

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")

# %%
print(df["Survived"].value_counts())
sns.countplot(df["Survived"])
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df["Embarked"])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Piechart

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%2f")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
sns.countplot(df["Survived"])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.pie(df["Survived"])
plt.show()

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct="%2f")
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %% [markdown]
# # Numerical Data
# ## a.Histogram

# %%
sns.histplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.style.use("fivethirtyeight")
plt.hist(df["Age"])
plt.show()

# %% [markdown]
# # Distplot

# %%
# It say the probality
sns.displot(df["Age"],color="red",kind='kde')

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# # Boxplot

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
sns.boxplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df["Fare"].mean()
# Out:
# 32.2042079685746

# %%
sns.boxplot(df["Fare"])
#plt.xlim(5, 50)
#plt.show()
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
sns.swarmplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>
